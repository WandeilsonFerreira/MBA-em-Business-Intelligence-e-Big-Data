# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
ocorrencia = pd.read_csv('/content/ocorrencia.csv', encoding="ISO-8859-1", sep=';')

# %%
ocorrencia.tail()
# Out:
#        codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 13180              28377               28377               28377
# 13181              28375               28375               28375
# 13182              28355               28355               28355
# 13183              28335               28335               28335
# 13184              28256               28256               28256
#
#        codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 13180               28377               28377                 ACIDENTE
# 13181               28375               28375                 ACIDENTE
# 13182               28355               28355                 ACIDENTE
# 13183               28335               28335                 ACIDENTE
# 13184               28256               28256                 ACIDENTE
#
#       ocorrencia_latitude ocorrencia_longitude ocorrencia_cidade  \
# 13180                 ***                  ***        IMPERATRIZ
# ...

# %%
ocorrencia['total_aeronaves_envolvidas'].describe()
# Out:
# count    13185.000000
# mean         1.008722
# std          0.098532
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          4.000000
# Name: total_aeronaves_envolvidas, dtype: float64

# %%
ocorrencia.count().isnull()
# Out:
# codigo_ocorrencia                 False
# codigo_ocorrencia1                False
# codigo_ocorrencia2                False
# codigo_ocorrencia3                False
# codigo_ocorrencia4                False
# ocorrencia_classificacao          False
# ocorrencia_latitude               False
# ocorrencia_longitude              False
# ocorrencia_cidade                 False
# ocorrencia_uf                     False
# ocorrencia_pais                   False
# ocorrencia_aerodromo              False
# ocorrencia_dia                    False
# ocorrencia_hora                   False
# investigacao_aeronave_liberada    False
# investigacao_status               False
# divulgacao_relatorio_numero       False
# divulgacao_relatorio_publicado    False
# divulgacao_dia_publicacao         False
# total_recomendacoes               False
# total_aeronaves_envolvidas        False
# ocorrencia_saida_pista            False
# dtype: bool

# %%
ocorrencia[['ocorrencia_aerodromo','ocorrencia_cidade', 'ocorrencia_uf']].value_counts()
# Out:
# ocorrencia_aerodromo  ocorrencia_cidade  ocorrencia_uf
# SBGR                  GUARULHOS          SP               627
# SBGL                  RIO DE JANEIRO     RJ               397
# SBKP                  CAMPINAS           SP               374
# SBSP                  SÃO PAULO          SP               319
# SBBR                  BRASÍLIA           DF               316
#                                                          ...
# FAER                  UNIÃO              PI                 1
#                       UNIÃO DA VITÓRIA   PR                 1
#                       UNIÃO DE MINAS     MG                 1
#                       URANDI             BA                 1
#                       TUMIRITINGA        MG                 1
# Name: count, Length: 2339, dtype: int64

# %%
#ocorrencia.drop(columns=['codigo_ocorrencia1','codigo_ocorrencia2','codigo_ocorrencia3','codigo_ocorrencia4'])
ocorrencia_drop = ocorrencia.drop(columns=['codigo_ocorrencia1','codigo_ocorrencia2','codigo_ocorrencia3','codigo_ocorrencia4'])
ocorrencia_drop.head(20)
# Out:
#     codigo_ocorrencia ocorrencia_classificacao ocorrencia_latitude  \
# 0               87125                INCIDENTE     -7.219166666666
# 1               87124                INCIDENTE     -18.88361111111
# 2               87123                INCIDENTE     -23.43555555555
# 3               87122                INCIDENTE     -29.71083333333
# 4               87121                INCIDENTE     -20.81722222222
# 5               87118                INCIDENTE     -15.87111111111
# 6               87117                INCIDENTE     -3.775833333333
# 7               87116                INCIDENTE                 NaN
# 8               87115                INCIDENTE     -9.510833333333
# 9               87114                INCIDENTE            -16.6325
# 10              87113                INCIDENTE            -22.9875
# 11              87112                INCIDENTE            -22.9875
# 12              87111                 ACIDENTE     -6.304444444444
# ...

# %%
ocorrencia_drop.value_counts()
# Out:
# codigo_ocorrencia  ocorrencia_classificacao  ocorrencia_latitude  ocorrencia_longitude  ocorrencia_cidade      ocorrencia_uf  ocorrencia_pais  ocorrencia_aerodromo  ocorrencia_dia  ocorrencia_hora  investigacao_aeronave_liberada  investigacao_status  divulgacao_relatorio_numero  divulgacao_relatorio_publicado  divulgacao_dia_publicacao  total_recomendacoes  total_aeronaves_envolvidas  ocorrencia_saida_pista
# 85239              ACIDENTE                  -26.21277777777      -48.53611111111       SÃO FRANCISCO DO SUL   SC             BRASIL           SSSS                  28/07/2024      17:25:00         SIM                             FINALIZADA           A-111/CENIPA/2024            SIM                             2025-04-22                 0                    1                           NÃO                       1
# ...

# %%
#ocorrencia_drop['ocorrencia_saida_pista'].value_counts()
ocorrencia_drop['total_aeronaves_envolvidas'].value_counts()
# Out:
# total_aeronaves_envolvidas
# 1    13073
# 2      107
# 3        3
# 0        1
# 4        1
# Name: count, dtype: int64

# %%
[['ocorrencia_classificacao',	'ocorrencia_cidade', 'ocorrencia_uf',	'ocorrencia_aerodromo',	'ocorrencia_dia',	'ocorrencia_hora', investigacao_aeronave_liberada	investigacao_status	divulgacao_relatorio_numero	divulgacao_relatorio_publicado	divulgacao_dia_publicacao	total_recomendacoes	total_aeronaves_envolvidas	ocorrencia_saida_pista
