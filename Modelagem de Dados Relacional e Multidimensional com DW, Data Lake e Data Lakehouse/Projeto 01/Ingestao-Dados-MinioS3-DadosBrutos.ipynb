# %%
# !pip install minio
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting minio
#   Downloading minio-7.2.10-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from minio) (2024.7.4)
# Requirement already satisfied: urllib3 in c:\programdata\anaconda3\lib\site-packages (from minio) (2.0.7)
# Requirement already satisfied: argon2-cffi in c:\programdata\anaconda3\lib\site-packages (from minio) (21.3.0)
# Collecting pycryptodome (from minio)
#   Downloading pycryptodome-3.21.0-cp36-abi3-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: typing-extensions in c:\programdata\anaconda3\lib\site-packages (from minio) (4.9.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\programdata\anaconda3\lib\site-packages (from argon2-cffi->minio) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->minio) (1.16.0)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->minio) (2.21)
# Downloading minio-7.2.10-py3-none-any.whl (93 kB)
#    ---------------------------------------- 0.0/93.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/93.9 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/93.9 kB ? eta -:--:--
#    ------------- -------------------------- 30.7/93.9 kB 262.6 kB/s eta 0:00:01
#    -------------------------- ------------- 61.4/93.9 kB 409.6 kB/s eta 0:00:01
#    ---------------------------------------- 93.9/93.9 kB 533.1 kB/s eta 0:00:00
# Downloading pycryptodome-3.21.0-cp36-abi3-win_amd64.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.1/1.8 MB 3.3 MB/s eta 0:00:01
#    -- ------------------------------------- 0.1/1.8 MB 1.4 MB/s eta 0:00:02
#    ----- ---------------------------------- 0.2/1.8 MB 2.1 MB/s eta 0:00:01
#    ------ --------------------------------- 0.3/1.8 MB 1.5 MB/s eta 0:00:01
#    ----------- ---------------------------- 0.5/1.8 MB 2.4 MB/s eta 0:00:01
#    -------------- ------------------------- 0.6/1.8 MB 2.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.1/1.8 MB 3.6 MB/s eta 0:00:01
#    ------------------------------ --------- 1.4/1.8 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  1.8/1.8 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 4.4 MB/s eta 0:00:00
# Installing collected packages: pycryptodome, minio
# Successfully installed minio-7.2.10 pycryptodome-3.21.0
# DEPRECATION: Loading egg at c:\programdata\anaconda3\lib\site-packages\vboxapi-1.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330

# %%
from minio import Minio
from minio.error import S3Error
import os

# %%
# Configurações de acesso ao MinIO
minio_client = Minio(
    "localhost:9000",  # URL do seu servidor MinIO
    access_key="i21sIddYwTbDINJ4dQJV",  # Substitua pelo seu access key
    secret_key="yxzuuRBRGsSd5hQ5fdDy7nRlYm1d4cSo9A6Kduch",  # Substitua pelo seu secret key
    secure=False  # Defina como True se estiver usando HTTPS
)

# %%
# Nome do bucket no MinIO
bucket_name = "dados-brutos-img-datalake"
# Diretório local com as imagens
local_directory = "img/"

# Função para copiar arquivos de imagem para o MinIO
def upload_images_to_minio(local_directory, bucket_name):
    # Verificar se o bucket existe e criar caso não exista
    if not minio_client.bucket_exists(bucket_name):
        minio_client.make_bucket(bucket_name)
        print(f"Bucket '{bucket_name}' criado com sucesso.")
    else:
        print(f"Bucket '{bucket_name}' já existe.")

    # Iterar sobre os arquivos do diretório local
    for file_name in os.listdir(local_directory):
        # Verificar se o arquivo é uma imagem
        if file_name.endswith(('.jpg', '.jpeg', '.png', '.gif', '.bmp')):
            file_path = os.path.join(local_directory, file_name)
            try:
                # Enviar arquivo para o MinIO
                minio_client.fput_object(
                    bucket_name,  # Nome do bucket
                    file_name,    # Nome do objeto no bucket
                    file_path     # Caminho do arquivo local
                )
                print(f"Imagem '{file_name}' copiada com sucesso para o bucket '{bucket_name}'.")
            except S3Error as e:
                print(f"Erro ao copiar '{file_name}': {e}")

# %%
# Executa a função para copiar as imagens
upload_images_to_minio(local_directory, bucket_name)
# Out:
# Bucket 'dados-brutos-img-datalake' já existe.
# Imagem '8ba3d874-0f52-44c8-81df-fb9ef5ef6f53.png' copiada com sucesso para o bucket 'dados-brutos-img-datalake'.
# Imagem 'af60271f-fa8b-49c0-8f07-0674962d6d42.png' copiada com sucesso para o bucket 'dados-brutos-img-datalake'.
# Imagem 'Arquitetura - CADIA - Solução Mensageria.png' copiada com sucesso para o bucket 'dados-brutos-img-datalake'.
# Imagem 'Aula Inaugural MBA em Bi e Big Data 20242 (1).png' copiada com sucesso para o bucket 'dados-brutos-img-datalake'.
# Imagem 'Autenticação de Segurança e Proteção.png' copiada com sucesso para o bucket 'dados-brutos-img-datalake'.
# Imagem 'Autenticação.png' copiada com sucesso para o bucket 'dados-brutos-img-datalake'.
# Imagem 'automatizarSpoon.png' copiada com sucesso para o bucket 'dados-brutos-img-datalake'.
# Imagem 'cadeiras-ocupadas.png' copiada com sucesso para o bucket 'dados-brutos-img-datalake'.
# Imagem 'CadUnico-twela2.png' copiada com sucesso para o bucket 'dados-brutos-img-datalake'.
# Imagem 'CadUnico.png' copiada com sucesso para o bucket 'dados-brutos-img-datalake'.
# Imagem 'Comprovante-REsidencia.png' copiada com sucesso para o bucket 'dados-brutos-img-datalake'.
# Imagem 'DALL·E-2024-01-19-13.50.32-A-realistic-image-of-data-engineers-working-on-large-data-structures-symbolizing-the-foundation-of-digital-transformation.-The-scene-includes-advance.jpeg' copiada com sucesso para o bucket 'dados-brutos-img-datalake'.
# Imagem 'declaracao-baixa-renda.png' copiada com sucesso para o bucket 'dados-brutos-img-datalake'.
# Imagem 'dvd-rental-sample-database-diagram.png' copiada com sucesso para o bucket 'dados-brutos-img-datalake'.
# Imagem 'e81588f3-17f6-4063-ae96-b9f743b8c55c.png' copiada com sucesso para o bucket 'dados-brutos-img-datalake'.
# Imagem 'eaef6e2b-0aac-406f-8580-5cde2f75f8ae.png' copiada com sucesso para o bucket 'dados-brutos-img-datalake'.
# Imagem 'effffigura.png' copiada com sucesso para o bucket 'dados-brutos-img-datalake'.
# Imagem 'Engenharia-e-Qualidade-de-Software.png' copiada com sucesso para o bucket 'dados-brutos-img-datalake'.
# Imagem 'Engenharia-infraestrutura-e-governanca-dados.png' copiada com sucesso para o bucket 'dados-brutos-img-datalake'.
