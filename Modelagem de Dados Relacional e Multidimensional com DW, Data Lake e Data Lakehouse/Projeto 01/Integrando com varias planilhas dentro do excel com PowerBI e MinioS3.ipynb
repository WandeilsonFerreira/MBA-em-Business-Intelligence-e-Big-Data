# %%
# !pip install pandas minio powerbiclient
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 0.0/317.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/317.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/317.3 MB ? eta -:--:--
#      -------------------------------------- 0.0/317.3 MB 325.1 kB/s eta 0:16:16
#      -------------------------------------- 0.1/317.3 MB 491.5 kB/s eta 0:10:46
#      -------------------------------------- 0.1/317.3 MB 654.9 kB/s eta 0:08:05
#      -------------------------------------- 0.2/317.3 MB 888.4 kB/s eta 0:05:57
#      ---------------------------------------- 0.3/317.3 MB 1.0 MB/s eta 0:05:17
#      ---------------------------------------- 0.4/317.3 MB 1.1 MB/s eta 0:04:45
#      ---------------------------------------- 0.6/317.3 MB 1.5 MB/s eta 0:03:31
#      ---------------------------------------- 0.7/317.3 MB 1.7 MB/s eta 0:03:02
# ...

# %%
from minio import Minio
import pandas as pd
import io

# Conectar ao MinIO
client = Minio(
    "localhost:9000",  # Substitua pelo seu endpoint MinIO
    access_key="i21sIddYwTbDINJ4dQJV",
    secret_key="yxzuuRBRGsSd5hQ5fdDy7nRlYm1d4cSo9A6Kduch",
    secure=False
)

# Baixar dados do bucket
obj = client.get_object("dados-enriquecidos-dw", "planilhas/dw/dim_produtos.xlsx")
data = pd.read_excel(io.BytesIO(obj.read()))

# Exibir dados carregados
print(data.head())
# Out:
#    COD_PRODUTO   DESCRICAO      TIPO_PRODUTO FABRICANTE    preco
# 0            1  Chocoloate          Alimento     Nestle    10.52
# 1            2   Televisão  EletroEletrônico    Samsung  1589.63
# 2            3     Celular  EletroEletrônico    Samsung  1458.25
# 3            4    Camiseta         Vestuario    Colombo    15.25
# 4            5  Mp3 Player  EletroEletrônico       Sony   458.36
